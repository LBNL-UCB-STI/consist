# %% [markdown]
# ## Consist Quickstart
#
# This notebook demonstrates Consist's core feature: caching with explicit provenance. You pass concrete inputs and config into `tracker.run(...)`, and Consist records what produced each output.
#
# By the end, you'll understand:
# - How Consist tracks provenance (what code/config/inputs produced each result)
# - How to skip redundant computation with caching
# - How to keep function boundaries explicit instead of relying on hidden framework state
# - How to query and inspect your runs

# %% [markdown]
# ## Installation
#
# If Consist is not installed yet, install the package in your environment:
#
# ```bash
# pip install consist
# ```
#
# We'll keep everything in the current working directory so you can see the artifacts on disk.

# %%
import shutil
from pathlib import Path

import pandas as pd

import consist
from consist import ExecutionOptions, Tracker

# Clean slate for reproducible notebook output. Keep the quickstart in its
# own subdirectory so it does not disturb other example notebooks.
run_dir = Path("./runs/quickstart")
if run_dir.exists():
    shutil.rmtree(run_dir)
run_dir.mkdir(parents=True, exist_ok=True)

db_path = run_dir / "provenance.duckdb"

# Tracker holds the run directory and the DuckDB provenance store.
tracker = Tracker(run_dir=run_dir, db_path=db_path)


def display_path(path: str | Path) -> str:
    """Show paths relative to the notebook directory when possible."""
    path = Path(path)
    try:
        return str(path.resolve().relative_to(Path.cwd().resolve()))
    except ValueError:
        return str(path)

# %% [markdown]
# ## Create a small input file
#
# We create a tiny CSV file to use as input. When you pass a file path in `inputs={...}`, Consist computes its content hash. This hash becomes part of the cache signature: if the same input file is used again with the same config, Consist recognizes it and returns cached results.

# %%
raw_path = run_dir / "raw.csv"
df = pd.DataFrame({"value": [0.1, 0.6, 0.9, 0.2]})
df.to_csv(raw_path, index=False)
display_path(raw_path)
# Out:
# 'runs/quickstart/raw.csv'

# %% [markdown]
# ## Define a step
#
# Use a plain Python function with an explicit I/O boundary: it accepts a path, reads the file, writes an output file, and returns a `dict[str, Path]` naming the artifacts it produced.
# At call time, declare the matching output keys in `outputs=[...]` so Consist logs them.
#
# Consist does not infer hidden dependencies or execution order for you. It records the inputs, config, and outputs you pass into `tracker.run(...)`.

# %%
def clean_data(raw_path: Path, threshold: float = 0.5) -> dict[str, Path]:
    df = pd.read_csv(raw_path)
    out_path = consist.output_path("cleaned", ext="parquet")
    cleaned = df[df["value"] > threshold].copy()
    cleaned.to_parquet(out_path, index=False)
    return {"cleaned": out_path}

# %% [markdown]
# ## Run it (cache miss)
#
# Call `tracker.run(...)` directly. The important pieces are:
# - `fn`: your plain Python function
# - `inputs`: concrete files or artifacts to hash and pass in
# - `config`: parameters that should participate in cache identity
#
# On this first run, Consist executes the function, records a run, and logs the returned output artifact.

# %%
result1 = tracker.run(
    fn=clean_data,
    inputs={"raw_path": raw_path},
    config={"threshold": 0.5},
    outputs=["cleaned"],
    execution_options=ExecutionOptions(input_binding="paths"),
)
print(f"Cache hit: {result1.cache_hit}")
# Out:
# Cache hit: False

# %%
cleaned_artifact = result1.outputs["cleaned"]
cleaned_df = consist.load_df(cleaned_artifact)
print(f"Artifact: {cleaned_artifact.id}")
print(f"Path: {display_path(cleaned_artifact.path)}")
cleaned_df.head()
# Out:
# Artifact: 60b619f7-7079-4857-bc31-cf06d5faaa9c
# Path: runs/quickstart/outputs/clean_data/clean_data_8b3a8372/cleaned.parquet
#    value
# 0    0.6
# 1    0.9

# %% [markdown]
# ## What Consist does not infer for you
#
# - It does not discover dependencies from global variables or notebook state.
# - It does not reorder steps for you; you call each step explicitly.
# - It records the files, config, and artifact references you pass into `tracker.run(...)`.
#
# That is the tradeoff: a little more explicit wiring in exchange for cache behavior and provenance you can inspect later.

# %% [markdown]
# ## Run it again (cache hit)
#
# Now run with identical inputs and config.
#
# Consist computes a fingerprint (signature) from:
# 1. Your function's code
# 2. The `config` dict
# 3. The hashes of `inputs` files
#
# Since we're using the same code, config, and input file, the signature matches a previous run. Instead of re-executing, Consist returns the cached result instantly.

# %%
result2 = tracker.run(
    fn=clean_data,
    inputs={"raw_path": raw_path},
    config={"threshold": 0.5},
    outputs=["cleaned"],
    execution_options=ExecutionOptions(input_binding="paths"),
)
print(f"Cache hit: {result2.cache_hit}")
# Out:
# Cache hit: True

# %% [markdown]
# ## Change config (cache miss)
#
# Now change `config` to use a different threshold (0.8 instead of 0.5).
#
# This changes the signature, so Consist must re-execute the function and record a new run.

# %%
result3 = tracker.run(
    fn=clean_data,
    inputs={"raw_path": raw_path},
    config={"threshold": 0.8},
    outputs=["cleaned"],
    execution_options=ExecutionOptions(input_binding="paths"),
)
print(f"Cache hit: {result3.cache_hit}")
# Out:
# Cache hit: False

# %% [markdown]
# ## Read the cache miss explanation
#
# The run record keeps a structured explanation on `run.meta["cache_miss_explanation"]`.
# That explanation is easiest to read alongside `run.identity_summary`: the summary
# shows the hashes that formed the cache key, and the miss explanation tells you
# which part likely changed.
#
# In this example, the useful part is not just that the run missed, but that the
# reason is `config_changed` and the changed key is `threshold`.
#
# That makes the explanation useful after the fact: you can inspect the run and see
# which part of the identity changed instead of guessing from the raw cache miss alone.

# %%
miss_run = tracker.get_run(result3.run.id)
summary = miss_run.identity_summary
explanation = miss_run.meta.get("cache_miss_explanation", {})

print("Identity summary:")
print("  signature:", summary["signature"])
print("  config_hash:", summary["config_hash"])
print("  input_hash:", summary["input_hash"])
print()
print("Cache miss explanation:")
print("  reason:", explanation.get("reason"))
print("  candidate run:", explanation.get("candidate_run_id"))
print("  matched components:", explanation.get("matched_components"))
print("  mismatched components:", explanation.get("mismatched_components"))
print(
    "  changed config keys:",
    explanation.get("details", {}).get("config_keys_changed", []),
)
# Out:
# Identity summary:
#   signature: 62e465aceb4aa82102eb7dc80aa5d0c46496da7c294a390d33a3ecb4bdd30cbc
#   config_hash: 272d41eb7273ee9a80629f4ac6d0da80d6ccfd6c9ae9e15756bb193c3ff71d27
#   input_hash: 299cd9d4b173a3aacf2e5b5cd2dc01efd1684ac95192ac3288921f26c141859a
#
# Cache miss explanation:
#   reason: config_changed
#   candidate run: clean_data_e3900fa0
#   matched components: ['input_hash', 'git_hash']
#   mismatched components: ['config_hash']
#   changed config keys: ['threshold']

# %% [markdown]
# ## Inspect recorded runs
#
# Query recent runs by model name (derived from function name). Notice the `cache_hit` flag shows which runs were executed vs. returned from cache.
#
# To filter runs by parameter values, see [Query Facets](../docs/usage-guide.md#query-facets-with-pivot_facets).

# %%
runs = tracker.find_runs(model="clean_data", limit=10)
[(run.id, run.status, run.meta.get("cache_hit", False)) for run in runs]
# Out:
# [('clean_data_bd23d334', 'completed', False),
#  ('clean_data_e3900fa0', 'completed', True),
#  ('clean_data_8b3a8372', 'completed', False)]

# %% [markdown]
# ## See the outputs on disk
#
# In this explicit-path pattern, Consist records the file you wrote; it does not relocate it under `run_dir`.
# That means `artifact.path` points at the concrete path returned by the function body.

# %%
print("Output artifact files:")
for label, result in [("threshold=0.5", result1), ("threshold=0.8", result3)]:
    path = result.outputs["cleaned"].as_path(tracker=tracker)
    print(f"  {label}: {display_path(path)}")

print("\nCleaned data (threshold=0.5):")
consist.load_df(result1.outputs["cleaned"])
# Out:
# Output artifact files:
#   threshold=0.5: runs/quickstart/outputs/clean_data/clean_data_8b3a8372/cleaned.parquet
#   threshold=0.8: runs/quickstart/outputs/clean_data/clean_data_bd23d334/cleaned.parquet
#
# Cleaned data (threshold=0.5):
#    value
# 0    0.6
# 1    0.9

# %% [markdown]
# ## Next Step
#
# Continue with `examples/01_beam_core_demo.ipynb` to see the same core ideas in a simple multi-step scenario workflow.
